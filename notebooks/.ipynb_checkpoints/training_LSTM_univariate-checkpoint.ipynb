# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Chargement les données

# %%
# Charger les données à partir du fichier csv
data_filename = "data/PowerConsumptionTetouan/Tetuan_City_power_consumption.csv"
df_dataset = data_gathering.load_dataset(data_filename, col_sep=",", b_rename_cols=True)

# %% [markdown]
# ## Définition des paramètres

# %%
# Paramètres des entrées et sortie
feat_name = "Consumption_Z3"

# Paramètres pour la création des bases de test et d'apprentissage
train_ratio = 0.8
win_size_hours = 1
time_sampling_mins = 10
b_scaler = True
scaler_str = "std"

# %% [markdown]
# ## Création des bases d'apprentissage et de test

# %% [markdown]
# #### Séparation temporelles des bases d'apprentissage et de test

# %% [markdown]
# #### Création des séquences temporelles
# Il faudra structurer les données en séquences temporelles afin de prendre en compte un historique

# %%
X_train, y_train, idx_train, X_test, y_test, idx_test, scaler = \
training.build_train_test_univariate_sequences(df_data=df_dataset,
                                               feat_name=feat_name,
                                               win_size_hours=win_size_hours,
                                               time_sampling_mins=time_sampling_mins,
                                               train_ratio=train_ratio,
                                               scaler_str=scaler_str)

# %% [markdown]
# ## Prédiction de la consommation

# %% [markdown]
# ### Entrainement du modèle

# %%
import os
from datetime import datetime
import pickle

# Paramètres d'apprentissage
d_learning_params = dict()
d_learning_params['batch_size'] = 1024
d_learning_params['epochs'] = 500
d_learning_params['activation_fn'] = "relu"
d_learning_params['loss_fn'] = "mse"
d_learning_params['optimizer'] = "adam"
d_learning_params['val_ratio'] = 0.2
d_learning_params['win_size_hours'] = win_size_hours
d_learning_params['time_sampling_mins'] = time_sampling_mins
d_learning_params['scaler'] = scaler
d_learning_params['feat_names'] = feat_name
d_learning_params['target_names'] = feat_name
d_learning_params['metrics'] = ['mae']
d_learning_params['d_train_test'] = {}
d_learning_params['seq_train_test'] = {"train":{"features":X_train, "targets":y_train, "targets_idx": idx_train},
                                       "test":{"features":X_test, "targets":y_test, "targets_idx": idx_test}}
d_learning_params['layers'] = [100, 50, 10]

# Récupérer la date et l'heure pour la création du fichier du modèle
current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")
results_dir = os.path.join("models", "Univariate_LSTM_{}h".format(win_size_hours), feat_name, current_datetime)
params_file = os.path.join(results_dir, "lstm_params_{}.pkl".format(str(current_datetime)))

# Création du répertoire de sauvegarde des résultats s'il n'existe pas déjà
if not os.path.exists(results_dir):
    os.makedirs(results_dir)

# Sauvergarde des paramètres d'appentissag
with open(params_file, 'wb') as fp:
    pickle.dump(d_learning_params, fp)

model_lstm, scores = training.train_lstm_univariate(X_train, y_train,
                                         X_test, y_test, 
                                         d_learning_params,
                                         results_dir)

# Sauvegarder les scores de ce modèle
d_scores = d_learning_params.copy()
d_scores["scores"] = scores
scores_file = os.path.join(results_dir, "lstm_scores_{}.pkl".format(str(current_datetime)))

print("Performance du modèle")
print("\t --> Score R2 (Le modèle parfait a un score de 1)")
print("\t \t --> Ensemble d'apprentissage : {}".format(scores['R2']['train']))
print("\t \t --> Ensemble de test : {}".format(scores['R2']['test']))
print("\n")
print("\t --> MAE (Erreur moyenne absolue) en KW")
print("\t \t --> Ensemble d'apprentissage : {}".format(scores['MAE']['train']))
print("\t \t --> Ensemble de test : {}".format(scores['MAE']['test']))

# Sauvergarde des paramètres d'appentissag
with open(scores_file, 'wb') as fp:
    pickle.dump(d_scores, fp)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 6, 100)            40800
#
#  lstm_1 (LSTM)               (None, 6, 50)             30200
#
#  lstm_2 (LSTM)               (None, 10)                2440
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 73,451
# Trainable params: 73,451
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 33/33 [==============================] - 6s 97ms/step - loss: 0.6720 - mae: 0.6354 - val_loss: 0.1182 - val_mae: 0.2231
# Epoch 2/500
# 33/33 [==============================] - 3s 91ms/step - loss: 0.0808 - mae: 0.1990 - val_loss: 0.0396 - val_mae: 0.1465
# Epoch 3/500
# 33/33 [==============================] - 3s 91ms/step - loss: 0.0446 - mae: 0.1459 - val_loss: 0.0258 - val_mae: 0.1111
# Epoch 4/500
# 33/33 [==============================] - 3s 95ms/step - loss: 0.0294 - mae: 0.1160 - val_loss: 0.0217 - val_mae: 0.1145
# Epoch 5/500
# 33/33 [==============================] - 3s 95ms/step - loss: 0.0157 - mae: 0.0873 - val_loss: 0.0081 - val_mae: 0.0661
# Epoch 6/500
# 33/33 [==============================] - 3s 96ms/step - loss: 0.0092 - mae: 0.0679 - val_loss: 0.0055 - val_mae: 0.0499
# Epoch 7/500
# 33/33 [==============================] - 3s 94ms/step - loss: 0.0068 - mae: 0.0575 - val_loss: 0.0074 - val_mae: 0.0670
# Epoch 8/500
# 33/33 [==============================] - 3s 98ms/step - loss: 0.0055 - mae: 0.0494 - val_loss: 0.0050 - val_mae: 0.0490
# Epoch 9/500
# 33/33 [==============================] - 3s 98ms/step - loss: 0.0054 - mae: 0.0504 - val_loss: 0.0040 - val_mae: 0.0416
# Epoch 10/500
# 33/33 [==============================] - 3s 98ms/step - loss: 0.0042 - mae: 0.0410 - val_loss: 0.0034 - val_mae: 0.0364
# Epoch 11/500
# 33/33 [==============================] - 3s 96ms/step - loss: 0.0058 - mae: 0.0544 - val_loss: 0.0030 - val_mae: 0.0334
# Epoch 12/500
# 33/33 [==============================] - 3s 97ms/step - loss: 0.0037 - mae: 0.0379 - val_loss: 0.0049 - val_mae: 0.0527
# Epoch 13/500
# 33/33 [==============================] - 3s 96ms/step - loss: 0.0041 - mae: 0.0435 - val_loss: 0.0036 - val_mae: 0.0423
# Epoch 14/500
# 33/33 [==============================] - 3s 95ms/step - loss: 0.0046 - mae: 0.0478 - val_loss: 0.0043 - val_mae: 0.0496
# Epoch 15/500
# 33/33 [==============================] - 3s 96ms/step - loss: 0.0038 - mae: 0.0409 - val_loss: 0.0116 - val_mae: 0.0970
# Epoch 16/500
# 33/33 [==============================] - 3s 94ms/step - loss: 0.0039 - mae: 0.0413 - val_loss: 0.0043 - val_mae: 0.0501
# Epoch 17/500
# 33/33 [==============================] - 3s 89ms/step - loss: 0.0040 - mae: 0.0439 - val_loss: 0.0026 - val_mae: 0.0316
# Epoch 18/500
# 33/33 [==============================] - 3s 88ms/step - loss: 0.0035 - mae: 0.0403 - val_loss: 0.0024 - val_mae: 0.0293
# Epoch 19/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0044 - mae: 0.0460 - val_loss: 0.0031 - val_mae: 0.0379
# Epoch 20/500
# 33/33 [==============================] - 3s 88ms/step - loss: 0.0034 - mae: 0.0393 - val_loss: 0.0028 - val_mae: 0.0350
# Epoch 21/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0033 - mae: 0.0379 - val_loss: 0.0032 - val_mae: 0.0408
# Epoch 22/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0039 - mae: 0.0448 - val_loss: 0.0025 - val_mae: 0.0318
# Epoch 23/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0033 - mae: 0.0385 - val_loss: 0.0027 - val_mae: 0.0351
# Epoch 24/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0029 - mae: 0.0353 - val_loss: 0.0064 - val_mae: 0.0680
# Epoch 25/500
# 33/33 [==============================] - 3s 88ms/step - loss: 0.0066 - mae: 0.0589 - val_loss: 0.0023 - val_mae: 0.0291
# Epoch 26/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0033 - mae: 0.0398 - val_loss: 0.0026 - val_mae: 0.0334
# Epoch 27/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0028 - mae: 0.0347 - val_loss: 0.0022 - val_mae: 0.0282
# Epoch 28/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0026 - mae: 0.0333 - val_loss: 0.0023 - val_mae: 0.0300
# Epoch 29/500
# 33/33 [==============================] - 3s 88ms/step - loss: 0.0028 - mae: 0.0352 - val_loss: 0.0021 - val_mae: 0.0275
# Epoch 30/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0029 - mae: 0.0363 - val_loss: 0.0022 - val_mae: 0.0298
# Epoch 31/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0028 - mae: 0.0351 - val_loss: 0.0022 - val_mae: 0.0297
# Epoch 32/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0038 - mae: 0.0437 - val_loss: 0.0022 - val_mae: 0.0296
# Epoch 33/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0028 - mae: 0.0357 - val_loss: 0.0021 - val_mae: 0.0278
# Epoch 34/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0028 - mae: 0.0354 - val_loss: 0.0028 - val_mae: 0.0378
# Epoch 35/500
# 33/33 [==============================] - 3s 89ms/step - loss: 0.0027 - mae: 0.0351 - val_loss: 0.0020 - val_mae: 0.0275
# Epoch 36/500
# 33/33 [==============================] - 3s 88ms/step - loss: 0.0027 - mae: 0.0347 - val_loss: 0.0023 - val_mae: 0.0320
# Epoch 37/500
# 33/33 [==============================] - 3s 89ms/step - loss: 0.0028 - mae: 0.0362 - val_loss: 0.0019 - val_mae: 0.0265
# Epoch 38/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0032 - mae: 0.0394 - val_loss: 0.0023 - val_mae: 0.0319
# Epoch 39/500
# 33/33 [==============================] - 3s 88ms/step - loss: 0.0025 - mae: 0.0335 - val_loss: 0.0047 - val_mae: 0.0573
# Epoch 40/500
# 33/33 [==============================] - 3s 88ms/step - loss: 0.0025 - mae: 0.0332 - val_loss: 0.0023 - val_mae: 0.0326
# Epoch 41/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0026 - mae: 0.0347 - val_loss: 0.0019 - val_mae: 0.0275
# Epoch 42/500
# 33/33 [==============================] - 3s 88ms/step - loss: 0.0026 - mae: 0.0345 - val_loss: 0.0019 - val_mae: 0.0264
# Epoch 43/500
# 33/33 [==============================] - 3s 89ms/step - loss: 0.0025 - mae: 0.0337 - val_loss: 0.0018 - val_mae: 0.0261
# Epoch 44/500
# 33/33 [==============================] - 3s 88ms/step - loss: 0.0030 - mae: 0.0381 - val_loss: 0.0019 - val_mae: 0.0271
# Epoch 45/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0028 - mae: 0.0364 - val_loss: 0.0019 - val_mae: 0.0276
# Epoch 46/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0029 - mae: 0.0380 - val_loss: 0.0021 - val_mae: 0.0302
# Epoch 47/500
# 33/33 [==============================] - 3s 89ms/step - loss: 0.0026 - mae: 0.0342 - val_loss: 0.0018 - val_mae: 0.0255
# Epoch 48/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0026 - mae: 0.0343 - val_loss: 0.0020 - val_mae: 0.0284
# Epoch 49/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0026 - mae: 0.0343 - val_loss: 0.0022 - val_mae: 0.0324
# Epoch 50/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0023 - mae: 0.0318 - val_loss: 0.0032 - val_mae: 0.0447
# Epoch 51/500
# 33/33 [==============================] - 3s 85ms/step - loss: 0.0026 - mae: 0.0346 - val_loss: 0.0020 - val_mae: 0.0299
# Epoch 52/500
# 33/33 [==============================] - 3s 85ms/step - loss: 0.0029 - mae: 0.0385 - val_loss: 0.0023 - val_mae: 0.0336
# Epoch 53/500
# 33/33 [==============================] - 3s 88ms/step - loss: 0.0023 - mae: 0.0316 - val_loss: 0.0018 - val_mae: 0.0261
# Epoch 54/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0022 - mae: 0.0300 - val_loss: 0.0022 - val_mae: 0.0322
# Epoch 55/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0026 - mae: 0.0352 - val_loss: 0.0017 - val_mae: 0.0256
# Epoch 56/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0025 - mae: 0.0341 - val_loss: 0.0020 - val_mae: 0.0301
# Epoch 57/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0024 - val_mae: 0.0348
# Epoch 58/500
# 33/33 [==============================] - 3s 88ms/step - loss: 0.0024 - mae: 0.0333 - val_loss: 0.0031 - val_mae: 0.0439
# Epoch 59/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0023 - mae: 0.0321 - val_loss: 0.0021 - val_mae: 0.0305
# Epoch 60/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0025 - mae: 0.0338 - val_loss: 0.0029 - val_mae: 0.0422
# Epoch 61/500
# 33/33 [==============================] - 3s 88ms/step - loss: 0.0022 - mae: 0.0310 - val_loss: 0.0017 - val_mae: 0.0255
# Epoch 62/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0022 - mae: 0.0311 - val_loss: 0.0036 - val_mae: 0.0496
# Epoch 63/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0023 - mae: 0.0321 - val_loss: 0.0017 - val_mae: 0.0256
# Epoch 64/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0022 - mae: 0.0307 - val_loss: 0.0017 - val_mae: 0.0255
# Epoch 65/500
# 33/33 [==============================] - 3s 89ms/step - loss: 0.0025 - mae: 0.0339 - val_loss: 0.0017 - val_mae: 0.0253
# Epoch 66/500
# 33/33 [==============================] - 3s 88ms/step - loss: 0.0022 - mae: 0.0314 - val_loss: 0.0018 - val_mae: 0.0278
# Epoch 67/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0023 - mae: 0.0320 - val_loss: 0.0021 - val_mae: 0.0313
# Epoch 68/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0025 - mae: 0.0349 - val_loss: 0.0017 - val_mae: 0.0256
# Epoch 69/500
# 33/33 [==============================] - 3s 88ms/step - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0017 - val_mae: 0.0253
# Epoch 70/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0021 - mae: 0.0299 - val_loss: 0.0022 - val_mae: 0.0337
# Epoch 71/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0022 - mae: 0.0306 - val_loss: 0.0025 - val_mae: 0.0362
# Epoch 72/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0026 - mae: 0.0360 - val_loss: 0.0018 - val_mae: 0.0260
# Epoch 73/500
# 33/33 [==============================] - 3s 88ms/step - loss: 0.0021 - mae: 0.0293 - val_loss: 0.0017 - val_mae: 0.0254
# Epoch 74/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0023 - mae: 0.0328 - val_loss: 0.0037 - val_mae: 0.0501
# Epoch 75/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0025 - mae: 0.0346 - val_loss: 0.0017 - val_mae: 0.0256
# Epoch 76/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0023 - mae: 0.0319 - val_loss: 0.0019 - val_mae: 0.0280
# Epoch 77/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0021 - mae: 0.0299 - val_loss: 0.0021 - val_mae: 0.0325
# Epoch 78/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0023 - mae: 0.0324 - val_loss: 0.0019 - val_mae: 0.0282
# Epoch 79/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0022 - mae: 0.0314 - val_loss: 0.0018 - val_mae: 0.0274
# Epoch 80/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0023 - mae: 0.0330 - val_loss: 0.0018 - val_mae: 0.0264
# Epoch 81/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0022 - mae: 0.0313 - val_loss: 0.0017 - val_mae: 0.0256
# Epoch 82/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0021 - mae: 0.0295 - val_loss: 0.0017 - val_mae: 0.0263
# Epoch 83/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0021 - mae: 0.0298 - val_loss: 0.0017 - val_mae: 0.0257
# Epoch 84/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0021 - mae: 0.0298 - val_loss: 0.0017 - val_mae: 0.0260
# Epoch 85/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0021 - mae: 0.0304 - val_loss: 0.0019 - val_mae: 0.0286
# Epoch 86/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0024 - mae: 0.0338 - val_loss: 0.0019 - val_mae: 0.0282
# Epoch 87/500
# 33/33 [==============================] - 3s 86ms/step - loss: 0.0024 - mae: 0.0335 - val_loss: 0.0025 - val_mae: 0.0365
# Epoch 88/500
# 33/33 [==============================] - 3s 87ms/step - loss: 0.0024 - mae: 0.0334 - val_loss: 0.0020 - val_mae: 0.0305
# 328/328 [==============================] - 1s 2ms/step
# 1311/1311 [==============================] - 2s 2ms/step
# Performance du modèle
# 	 --> Score R2 (Le modèle parfait a un score de 1)
# 	 	 --> Ensemble d'apprentissage : 0.998
# 	 	 --> Ensemble de test : 0.986
#
#
# 	 --> MAE (Erreur moyenne absolue) en KW
# 	 	 --> Ensemble d'apprentissage : 187.552
# 	 	 --> Ensemble de test : 297.197

# %% [markdown]
# ### Affichage des prédictions

# %%
from src.prediction import display_prediction

# Calculer les prédictions
# Attention à appliquer la normalisation inverse pour retrouver l'échelle initiale
pred_col_name = ["prediction"]
df_test = pd.DataFrame(data=d_learning_params['scaler'].inverse_transform(y_test), columns=[feat_name],index=idx_test)
df_test[pred_col_name[0]] = d_learning_params['scaler'].inverse_transform(model_lstm.predict(X_test))

# Sauvegarde des résultats
df_test.to_pickle(os.path.join(results_dir, "lstm_predictions_{}_{}.pkl".format(feat_name, str(current_datetime))))

# Afficher les résultats
display_prediction(df_test, target_col_name=feat_name,
                   pred_col_name=pred_col_name, figsize=(14, 8))
# Out:
# 328/328 [==============================] - 1s 2ms/step

# %%
df_test["2017-11-20":"2017-11-30"].plot()
# Out:
# <Axes: >
